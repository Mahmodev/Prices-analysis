# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import NaN
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 180)
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
df1 = pd.read_csv('Datasets/Fashion_May_24/fashion.csv')
df2 = pd.read_csv('Datasets/Fashion_May_24/2.csv')

# %%
df = pd.concat([df1, df2])

# %%
gdf['Stars'] = gdf['Stars'].str.replace(' out of 5 stars','')
gdf['Price'] = gdf['Price'].str.replace('EGP', '')
gdf['Price'] = gdf['Price'].str.replace(',', '')
gdf['Price'] = gdf['Price'].str.replace('\xa0', '')
gdf['OldPrice'] = gdf['OldPrice'].str.replace('EGP', '')
gdf['OldPrice'] = gdf['OldPrice'].str.replace(',', '')
gdf['OldPrice'] = gdf['OldPrice'].str.replace('\xa0', '')

# %%
df = gdf.drop_duplicates(subset=['Name', 'Price', 'OldPrice','Stars','BestSeller'], keep='first', inplace=False)

# %%
df['Price'].unique()
# Out:
# array(['6199.00', '7270.00', '420.00', ..., '27.74', '1775.45', '37.04'],
#       dtype=object)

# %%
df['OldPrice'].unique()
# Out:
# array([nan, '5549.00', '11199.00', '7199.00', '2199.00', '399.00',
#        '3299.00', '7999.00', '2599.00', '1150.00', '3999.00', '381.02',
#        '8249.00', '9799.00', '448.36', '6160.00', '10799.00', '162.39',
#        '15999.00', '4130.45', '7399.00', '4799.00', '1403.57', '571.20',
#        '256.00', '2499.00', '6199.00', '638.40', '9349.00', '345.02',
#        '98.42', '2999.00', '733.32', '22499.00', '9099.00', '1559.52',
#        '219.90', '11899.00', '240.62', '1481.54', '999.00', '302.40',
#        '3399.00', '3355.02', '68.16', '2261.30', '1249.00', '1099.00',
#        '703.98', '4599.00', '152.00', '10499.00', '5399.00', '495.91',
#        '1176.00', '2879.92', '3590.00', '235.10', '980.00', '267.07',
#        '10740.00', '177.69', '136.80', '185.60', '12999.00', '760.00',
#        '30.00', '922.80', '792.35', '2713.20', '4499.00', '798.40',
#        '102.43', '269.00', '249.00', '3189.00', '930.24', '45.50',
# ...

# %%
df = df[df.Price != 'Price'] # Delete Row has strings of the columns name

# %%
df['Price'] = df["Price"].astype('float')

# %%
df['OldPrice'] = df["OldPrice"].astype('float')

# %%
df['Stars'] = df["Stars"].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8568 entries, 0 to 141
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8568 non-null   object
#  1   Link        8568 non-null   object
#  2   Price       8567 non-null   float64
#  3   OldPrice    1439 non-null   float64
#  4   BestSeller  800 non-null    object
#  5   Stars       873 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 468.6+ KB

# %%
df['Discount'] = (1-(df['Price']/df['OldPrice']))*100

# %%
df.rename(columns={"Price": "May17", "OldPrice": "OldMay17"})
# Out:
#                                                                                           Name  \
# 0                          Samsung Galaxy A52 Dual Sim, 128GB, 8GB RAM, 4G LTE - Awesome Black
# 1                            Samsung Galaxy A52 Dual SIM - 6.5 inches, 8 GB RAM, 128 GB - Blue
# 2                                                                Nokia 106 Dual SIM- Dark Grey
# 3                                     Samsung Galaxy A52s Dual SIM - 128GB, 8GB RAM, 5G, BLACK
# 4                     Toshiba LED 43 Inch Full HD TV with Built-In Receiver, Black - 43L3965EA
# ..                                                                                         ...
# 133                                             Borofone BU3 Blinkjet Type C USB Cable - Black
# 134  Godox SK300 Professionale Studio Strobe Serie SK 220V-Potenza-5600-K-Max-300WS-GN58-flash
# 138                                           X26 Xpress charging data cable for lightning red
# ...

# %%
ndf1 = pd.read_csv('Datasets/elec_may_21/1.csv')
ndf2 = pd.read_csv('Datasets/elec_may_21/2.csv')
ndf3 = pd.read_csv('Datasets/elec_may_21/3.csv')
ndf4 = pd.read_csv('Datasets/elec_may_21/4.csv')
ndf5 = pd.read_csv('Datasets/elec_may_21/5.csv')
ndf6 = pd.read_csv('Datasets/elec_may_21/6.csv')
ndf7 = pd.read_csv('Datasets/elec_may_21/7.csv')
ndf8 = pd.read_csv('Datasets/elec_may_21/8.csv')

# %%
ngdf = pd.concat([ndf1, ndf2, ndf3, ndf4, ndf5, ndf6, ndf7, ndf8])

# %%
ngdf['Stars'] = ngdf['Stars'].str.replace(' out of 5 stars','')
ngdf['Price'] = ngdf['Price'].str.replace('EGP', '')
ngdf['Price'] = ngdf['Price'].str.replace(',', '')
ngdf['Price'] = ngdf['Price'].str.replace('\xa0', '')
ngdf['OldPrice'] = ngdf['OldPrice'].str.replace('EGP', '')
ngdf['OldPrice'] = ngdf['OldPrice'].str.replace(',', '')
ngdf['OldPrice'] = ngdf['OldPrice'].str.replace('\xa0', '')

# %%
ngdf.head(10)
# Out:
#                                                                                 Name  \
# 0                Samsung Galaxy A52 Dual Sim, 128GB, 8GB RAM, 4G LTE - Awesome Black
# 1     Samsung Galaxy A12 Dual SIM Mobile - 6.5 Inch, 64 GB, 4 GB RAM, 4G LTE - Black
# 2                                                      Nokia 106 Dual SIM- Dark Grey
# 3                  Samsung Galaxy A52 Dual SIM - 6.5 inches, 8 GB RAM, 128 GB - Blue
# 4                           Samsung Galaxy A52s Dual SIM - 128GB, 8GB RAM, 5G, BLACK
# 5           Toshiba LED 43 Inch Full HD TV with Built-In Receiver, Black - 43L3965EA
# 6   Samsung Galaxy A32 Dual SIM - 6.4 Inches, 6GB RAM, 128GB, 4G LTE - Awesome Black
# 7  Samsung 55 Inch 4K Ultra HD Smart Curved LED TV with Built-in Receiver UA55TU8300
# 8      Xiaomi Redmi Note 10S Dual SIM Amoled Display Ocean Blue 6GB RAM 128GB 4G LTE
# 9                                       Reno 6 Black Dual Sim 8GB RAM 128GB 4G LTE -
#
# ...

# %%
ngdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9624 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9624 non-null   object
#  1   Link        9624 non-null   object
#  2   Price       9624 non-null   object
#  3   OldPrice    1525 non-null   object
#  4   BestSeller  905 non-null    object
#  5   Stars       1005 non-null   object
# dtypes: object(6)
# memory usage: 526.3+ KB

# %%
ndf = ngdf.drop_duplicates(subset=['Name', 'Price', 'OldPrice','Stars','BestSeller'], keep='first', inplace=False)

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9255 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9255 non-null   object
#  1   Link        9255 non-null   object
#  2   Price       9255 non-null   object
#  3   OldPrice    1485 non-null   object
#  4   BestSeller  875 non-null    object
#  5   Stars       995 non-null    object
# dtypes: object(6)
# memory usage: 506.1+ KB

# %%
ndf.OldPrice.unique()
# Out:
# array([nan, '5549.00', '11199.00', '7199.00', '2199.00', '8249.00',
#        '7999.00', '2599.00', '399.00', '3299.00', '1150.00', '3999.00',
#        '381.02', '448.36', '4799.00', '7399.00', '162.39', '6160.00',
#        '4130.45', '15999.00', '10799.00', '1403.57', '6199.00', '116.25',
#        '638.40', '9349.00', '256.00', '571.20', '3355.02', '9099.00',
#        '100.00', '2499.00', '98.42', '224.00', '1559.52', '733.32',
#        '345.02', '11899.00', '240.62', '2999.00', '22499.00', '1481.54',
#        '1249.00', '5400.00', '9499.00', '68.16', '3399.00', '302.40',
#        '4599.00', '1099.00', '3590.00', '999.00', '13499.00', '703.98',
#        '2261.30', '152.00', '8852.84', '5399.00', '1176.00', '495.91',
#        '30000.00', '235.10', '2879.92', '10740.00', '185.60', '10499.00',
#        '267.07', '177.69', '922.80', '5199.00', '129.60', '4060.00',
#        '760.00', '9599.00', '958.40', '798.40', '249.00', '102.43',
# ...

# %%
ndf.Price = ndf.Price.astype('float')
ndf.OldPrice = ndf.OldPrice.astype('float')
ndf.Stars = ndf.Stars.astype('float')
# Out:
# /tmp/ipykernel_69141/495654846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf.Price = ndf.Price.astype('float')
# /tmp/ipykernel_69141/495654846.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf.OldPrice = ndf.OldPrice.astype('float')
# /tmp/ipykernel_69141/495654846.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9255 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9255 non-null   object
#  1   Link        9255 non-null   object
#  2   Price       9255 non-null   float64
#  3   OldPrice    1485 non-null   float64
#  4   BestSeller  875 non-null    object
#  5   Stars       995 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 506.1+ KB

# %%
ndf['Discount'] = (1-(ndf['Price']/ndf['OldPrice']))*100
ndf.head(20)
# Out:
# /tmp/ipykernel_69141/1142568093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf['Discount'] = (1-(ndf['Price']/ndf['OldPrice']))*100
#                                                                                                                                                                         Name  \
# 0                                                                                                        Samsung Galaxy A52 Dual Sim, 128GB, 8GB RAM, 4G LTE - Awesome Black
# 1                                                                                             Samsung Galaxy A12 Dual SIM Mobile - 6.5 Inch, 64 GB, 4 GB RAM, 4G LTE - Black
# ...

# %%
ndf.rename(columns={"Price": "May21", "OldPrice": "OldMay21"})
# Out:
#                                                                                                         Name  \
# 0                                        Samsung Galaxy A52 Dual Sim, 128GB, 8GB RAM, 4G LTE - Awesome Black
# 1                             Samsung Galaxy A12 Dual SIM Mobile - 6.5 Inch, 64 GB, 4 GB RAM, 4G LTE - Black
# 2                                                                              Nokia 106 Dual SIM- Dark Grey
# 3                                          Samsung Galaxy A52 Dual SIM - 6.5 inches, 8 GB RAM, 128 GB - Blue
# 4                                                   Samsung Galaxy A52s Dual SIM - 128GB, 8GB RAM, 5G, BLACK
# ..                                                                                                       ...
# 43                                Huawei Honor 8X Case, Crystal Clear air Cushion anti Crack Slim back cover
# ...

# %%
# combine The two dataframe
ddf = pd.merge(df, ndf, on='Name')

# %%
ddf = ddf.drop(columns=['Stars_x', 'Stars_y','Discount_x','Discount_y'])

# %%
ddf['Link_x'] = 'https://www.amazon.eg' + ddf['Link_x'].astype(str)
ddf['Link_y'] = 'https://www.amazon.eg' + ddf['Link_y'].astype(str)

# %%
ddf['Drop'] = (1-(ddf['Price_y']/ddf['Price_x']))*100

# %%
for i in range (0, len(ddf['Link_x'])):
    if ddf['Link_x'][i] == 'd' and ddf['Link_x'][i+1] == 'p':
        ddf['Link_x'] = ddf['Link_x'][0:i+13]
        break
for x in range (0, len(ddf['Link_y'])):
    if ddf['Link_y'][x] == 'd' and ddf['Link_y'][x+1] == 'p':
        ddf['Link_y'] = ddf['Link_y'][0:x+13]
        break

ddf.head(10)
# Out:
#                                                                                 Name  \
# 0                Samsung Galaxy A52 Dual Sim, 128GB, 8GB RAM, 4G LTE - Awesome Black
# 1                  Samsung Galaxy A52 Dual SIM - 6.5 inches, 8 GB RAM, 128 GB - Blue
# 2                                                      Nokia 106 Dual SIM- Dark Grey
# 3                           Samsung Galaxy A52s Dual SIM - 128GB, 8GB RAM, 5G, BLACK
# 4                           Samsung Galaxy A52s Dual SIM - 128GB, 8GB RAM, 5G, BLACK
# 5                           Samsung Galaxy A52s Dual SIM - 128GB, 8GB RAM, 5G, BLACK
# 6                           Samsung Galaxy A52s Dual SIM - 128GB, 8GB RAM, 5G, BLACK
# 7           Toshiba LED 43 Inch Full HD TV with Built-In Receiver, Black - 43L3965EA
# 8      Xiaomi Redmi Note 10S Dual SIM Amoled Display Ocean Blue 6GB RAM 128GB 4G LTE
# 9  Samsung 55 Inch 4K Ultra HD Smart Curved LED TV with Built-in Receiver UA55TU8300
#
# ...

# %%
drop_10 = ddf[ddf['Drop']>10]

# %%
# drop_10.sort_values(by=['Price_y'], ascending = False)

# %%
ddf.Name.unique()
# Out:
# array(['Samsung Galaxy A52 Dual Sim, 128GB, 8GB RAM, 4G LTE - Awesome Black',
#        'Samsung Galaxy A52 Dual SIM - 6.5 inches, 8 GB RAM, 128 GB - Blue',
#        'Nokia 106 Dual SIM- Dark Grey', ...,
#        'Hoco M52 amazing Rhyme Wired Earphones with Microphone, 3.5 mm - White',
#        '21D Ceramic Matte Screen Protector For Xiaomi Redmi Note 5 Pro - Black',
#        'Xiaomi Note 9s / Note 9 Pro/Note 9 Pro Max 5D Full Screen Protector Black Frame - By Dl3 Mobailk'],
#       dtype=object)
